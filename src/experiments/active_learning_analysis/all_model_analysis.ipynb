# %%
"""
Active Learning Metrics — multi-dataset, multi-model full analysis
Datasets: gpqa, gsm8k, mmlu
Metrics : Random | H | EG (ex-BALD+) | ER (ex-SNR)
Entropy : max-normalised only
"""

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.lines import Line2D
from matplotlib.patches import Rectangle

# ──────────────────────────────────────────────────────────────────────────────
# CONFIGURATION
# ──────────────────────────────────────────────────────────────────────────────
DATA_DIR  = "./"          # ← folder with all *.parquet files
K_EVAL    = 0.10          # default evaluation budget
K_FRACS   = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.40, 0.50]
EPS       = 1e-8
CONF_THR  = 0.30          # Ĥ(t) threshold: below → confident teacher

# Available models per dataset  (order doesn't matter)
# small models (≤5B) → students | large models (>5B) → teachers
# large_llm_combined is excluded entirely
STUDENTS = ["llama_3b", "phi4mini", "qwen_3b"]
TEACHERS  = ["llama_70b", "mistral_24b", "qwen_32b", "qwen_72b"]

DATASETS = {
    "gpqa":  {"students": STUDENTS,
              "teachers": ["llama_70b", "mistral_24b", "qwen_32b", "qwen_72b"]},
    "gsm8k": {"students": STUDENTS,
              "teachers": ["llama_70b", "mistral_24b", "qwen_32b", "qwen_72b"]},
    "mmlu":  {"students": STUDENTS,
              "teachers": ["llama_70b", "mistral_24b", "qwen_32b", "qwen_72b"]},
}

# Explicit student-teacher pair to use for plots (one per dataset).
# Change these to any valid (student, teacher) combination from DATASETS above.
PLOT_PAIRS = {
    "gpqa":  ("qwen_3b", "qwen_72b"),
    "gsm8k": ("qwen_3b", "qwen_72b"),
    "mmlu":  ("qwen_3b", "qwen_72b"),
}

METRIC_COLORS = {
    "Random":           "#9ca3af",
    "H":                "#3b82f6",
    "EG":               "#14b8a6",
    "ER":               "#10b981",
    "Window-Product":   "#ec4899",
    "Window-Ratio":     "#8b5cf6",
    "Window-Log (IDS)": "#f59e0b",
    "LI":               "#ef4444",
}

DEFINITIONS = (
    "HV (High-Value) = teacher correct & student wrong → max learning signal  |  "
    "Confident Noise = teacher wrong & Ĥ(t) < 0.30 → confidently wrong label  |  "
    "Uncertainty Noise = teacher wrong & Ĥ(t) ≥ 0.30 → uncertain / noisy label"
)

# ──────────────────────────────────────────────────────────────────────────────
# DATA LOADING
# ──────────────────────────────────────────────────────────────────────────────


def load_model(dataset: str, model: str) -> pd.DataFrame:
    """Load parquet, return standardised 3-column frame: question_id, H, correct.

    Entropy priority: first_token_entropy (if present) → entropy_value.
    """
    path = os.path.join(DATA_DIR, f"{dataset}_{model}.parquet")
    df = pd.read_parquet(path)

    if "first_token_entropy" in df.columns:
        ent_col = "first_token_entropy"
    elif "entropy_value" in df.columns:
        ent_col = "entropy_value"
    elif "distill_entropy" in df.columns:
        ent_col = "distill_entropy"
    else:
        raise KeyError(
            f"{dataset}_{model}: no entropy column found. "
            f"Available columns: {list(df.columns)}"
        )

    # distill_entropy files use distill_ans_correct instead of model_answer_correct
    cor_col = "distill_ans_correct" if "model_answer_correct" not in df.columns else "model_answer_correct"

    print(f"  [entropy] {dataset}_{model}: using '{ent_col}', correct='{cor_col}'")

    out = df[["question_id", ent_col, cor_col]].copy()
    out = out.rename(columns={ent_col: "entropy_value", cor_col: "model_answer_correct"})
    out["entropy_value"] = out["entropy_value"].astype(float)
    return out


def build_pair(dataset: str, student: str, teacher: str) -> pd.DataFrame:
    """Inner-join student and teacher frames on question_id."""
    s = load_model(dataset, student).rename(
            columns={"entropy_value": "H_s", "model_answer_correct": "student_correct"})
    t = load_model(dataset, teacher).rename(
            columns={"entropy_value": "H_t", "model_answer_correct": "teacher_correct"})
    df = s.merge(t, on="question_id").copy()
    df["student_correct"] = df["student_correct"].astype(bool)
    df["teacher_correct"] = df["teacher_correct"].astype(bool)
    return df

# ──────────────────────────────────────────────────────────────────────────────
# METRICS  (max-normalised entropies only)
# ──────────────────────────────────────────────────────────────────────────────

def get_metric_scores(df: pd.DataFrame):
    """Return dict of score arrays + normalised entropy arrays."""
    H_s = df["H_s"].values.astype(float)
    H_t = df["H_t"].values.astype(float)
    Hs_n = H_s / (H_s.max() + EPS)
    Ht_n = H_t / (H_t.max() + EPS)

    rng = np.random.RandomState(42)
    Hs_var = Hs_n * (1 - Hs_n)   # Fisher Information signal term
    # P_t proxy: teacher confidence ≈ 1 - Ĥ(t)
    Pt_proxy = 1 - Ht_n
    scores = {
        "Random":           rng.rand(len(df)),
        "H":                Hs_n,
        "EG":               np.maximum(Hs_n - Ht_n, 0),          # formerly BALD+
        "ER":               Hs_n**2 / np.maximum(Ht_n**2, EPS),  # formerly SNR
        "Window-Product":   Hs_var * (1 - Ht_n),
        "Window-Ratio":     Hs_var / np.maximum(Ht_n, EPS),
        "Window-Log (IDS)": np.log1p(Hs_var / np.maximum(Ht_n, EPS)),
        "LI":               np.maximum(Hs_n - Ht_n, 0) * Pt_proxy,
    }
    return scores, Hs_n, Ht_n

# ──────────────────────────────────────────────────────────────────────────────
# EVALUATION
# ──────────────────────────────────────────────────────────────────────────────

def evaluate_at_k(score_arr: np.ndarray, df: pd.DataFrame, k_frac: float) -> dict:
    H_t  = df["H_t"].values.astype(float)
    Ht_n = H_t / (H_t.max() + EPS)
    sc   = df["student_correct"].values
    tc   = df["teacher_correct"].values

    is_hv          = tc & ~sc
    is_noisy       = ~tc
    is_conf_noise  = is_noisy & (Ht_n <  CONF_THR)
    is_unc_noise   = is_noisy & (Ht_n >= CONF_THR)

    k   = max(1, int(len(score_arr) * k_frac))
    idx = np.argsort(-score_arr)[:k]

    return {
        "HV":               is_hv[idx].mean(),
        "Confident_Noise":  is_conf_noise[idx].mean(),
        "Uncertainty_Noise":is_unc_noise[idx].mean(),
        "student_acc":      sc[idx].mean(),
        "teacher_acc":      tc[idx].mean(),
        "avg_Hs":           df["H_s"].values[idx].mean(),
        "avg_Ht":           df["H_t"].values[idx].mean(),
    }

# ──────────────────────────────────────────────────────────────────────────────
# PRINT HELPERS
# ──────────────────────────────────────────────────────────────────────────────

def print_table(results_dict: dict, k_frac: float = 0.10, label: str = ""):
    print(f"\n{'='*115}")
    print(f"  RANKING TABLE — top {int(k_frac*100)}%   {label}")
    print(f"{'='*115}")
    base_hv = results_dict["Random"][k_frac]["HV"]
    print(f"  {'Metric':<8} {'HV%':>7} {'ConfNoise%':>12} {'UncNoise%':>11} "
          f"{'S.Acc':>7} {'T.Acc':>7} {'Lift HV':>9}")
    print("-" * 115)
    ranked = sorted(results_dict, key=lambda n: -results_dict[n][k_frac]["HV"])
    for i, name in enumerate(ranked, 1):
        r    = results_dict[name][k_frac]
        lift = (r["HV"] - base_hv) / base_hv * 100 if base_hv > 0 else 0
        lift_str = "baseline" if name == "Random" else f"{lift:+.1f}%"
        print(f"  {i}. {name:<6} {r['HV']*100:>6.1f}%  {r['Confident_Noise']*100:>10.1f}%  "
              f"{r['Uncertainty_Noise']*100:>9.1f}%  {r['student_acc']*100:>6.1f}%  "
              f"{r['teacher_acc']*100:>6.1f}%  {lift_str:>9}")


def fmt_pct(x):
    return f"{x:.1%}" if isinstance(x, (float, np.floating)) else x

# ──────────────────────────────────────────────────────────────────────────────
# MAIN LOOP
# ──────────────────────────────────────────────────────────────────────────────
all_rows  = []
ds_rows   = {ds: [] for ds in DATASETS}

for dataset, cfg in DATASETS.items():
    for teacher in cfg["teachers"]:
        for student in cfg["students"]:
            try:
                df = build_pair(dataset, student, teacher)
            except FileNotFoundError as e:
                print(f"  [skip] {e}")
                continue

            scores, Hs_n, Ht_n = get_metric_scores(df)

            sc, tc = df["student_correct"].values, df["teacher_correct"].values
            is_hv  = tc & ~sc
            print(f"\n[{dataset}] student={student}  teacher={teacher}  n={len(df)}")
            print(f"  S.acc={sc.mean():.3f}  T.acc={tc.mean():.3f}  "
                  f"HV={(is_hv).mean():.1%}  Noisy={(~tc).mean():.1%}")

            # Full results across all budgets
            results = {
                name: {kf: evaluate_at_k(arr, df, kf) for kf in K_FRACS}
                for name, arr in scores.items()
            }

            for kf in [0.05, 0.10, 0.20]:
                print_table(results, kf, label=f"[{dataset} | {student} → {teacher}]")

            # Collect top-10% row for summary tables
            for name, arr in scores.items():
                r = evaluate_at_k(arr, df, K_EVAL)
                row = dict(Dataset=dataset, Student=student, Teacher=teacher,
                           Metric=name, **{k: v for k, v in r.items()
                                           if k not in ("avg_Hs", "avg_Ht")})
                all_rows.append(row)
                ds_rows[dataset].append(row)

            # (plot pairs are loaded separately via PLOT_PAIRS below)

# ──────────────────────────────────────────────────────────────────────────────
# ★  BIG TABLE  ★
# ──────────────────────────────────────────────────────────────────────────────
big_df = pd.DataFrame(all_rows)
display_df = big_df.copy()
for col in ["HV", "Confident_Noise", "Uncertainty_Noise", "student_acc", "teacher_acc"]:
    display_df[col] = display_df[col].map(fmt_pct)

print("\n\n" + "=" * 130)
print("  ★  BIG TABLE — all datasets × student models × metrics  (top 10%)  ★")
print("=" * 130)
pd.set_option("display.max_rows", 500, "display.width", 200)
print(display_df.to_string(index=False))

# ──────────────────────────────────────────────────────────────────────────────
# PER-DATASET TABLES (3 tables)
# ──────────────────────────────────────────────────────────────────────────────
for dataset in DATASETS:
    rows = ds_rows[dataset]
    if not rows:
        continue
    ds_df = pd.DataFrame(rows).drop(columns=["Dataset"])
    for col in ["HV", "Confident_Noise", "Uncertainty_Noise", "student_acc", "teacher_acc"]:
        ds_df[col] = ds_df[col].map(fmt_pct)
    print(f"\n\n{'='*115}")
    print(f"  DATASET: {dataset.upper()}")
    print(f"{'='*115}")
    print(ds_df.to_string(index=False))

# ──────────────────────────────────────────────────────────────────────────────
# PLOTS  (explicit pairs defined in PLOT_PAIRS above)
# ──────────────────────────────────────────────────────────────────────────────
plt.rcParams.update({
    "figure.facecolor": "white", "axes.facecolor": "white",
    "axes.grid": True, "grid.alpha": 0.3,
    "font.family": "sans-serif", "font.size": 10,
})

for dataset, (student, teacher) in PLOT_PAIRS.items():
    print(f"\n[plots] {dataset}: student={student}  teacher={teacher}")
    try:
        df = build_pair(dataset, student, teacher)
    except FileNotFoundError as e:
        print(f"  [skip plots] {e}")
        continue
    scores, Hs_n, Ht_n = get_metric_scores(df)
    sc  = df["student_correct"].values
    tc  = df["teacher_correct"].values
    H_s = df["H_s"].values
    H_t = df["H_t"].values

    is_hv  = tc & ~sc
    is_noisy = ~tc

    results_plot = {
        name: {kf: evaluate_at_k(arr, df, kf) for kf in K_FRACS}
        for name, arr in scores.items()
    }
    fracs_pct = [int(kf * 100) for kf in K_FRACS]

    # ── Fig 1: bar charts ──────────────────────────────────────────────────────
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    kf = 0.10
    for ax, key, title, ascending in [
        (axes[0], "HV",      f"High-Value Rate @ top 10% (↑)  [{dataset}]", False),
        (axes[1], "Confident_Noise",
                             f"Confident Noise Rate @ top 10% (↓)  [{dataset}]", True),
    ]:
        data = [(n, results_plot[n][kf][key]) for n in scores]
        data.sort(key=lambda x: x[1], reverse=not ascending)
        names = [d[0] for d in data]; vals = [d[1] for d in data]
        colors = [METRIC_COLORS[n] for n in names]
        bars = ax.barh(range(len(names)), vals, color=colors,
                       edgecolor="white", linewidth=0.5, height=0.7)
        ax.set_yticks(range(len(names)))
        ax.set_yticklabels(names, fontsize=9, fontfamily="monospace")
        ax.set_title(title, fontsize=11, fontweight="bold", pad=8)
        ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
        ax.invert_yaxis()
        base_val = results_plot["Random"][kf][key]
        ax.axvline(base_val, color="#ef4444", linestyle="--", alpha=0.5,
                   linewidth=1.2, label=f"Random ({base_val:.1%})")
        ax.legend(fontsize=8)
        for bar, val in zip(bars, vals):
            ax.text(bar.get_width() + 0.003, bar.get_y() + bar.get_height() / 2,
                    f"{val:.1%}", va="center", fontsize=9, fontfamily="monospace")

    fig.suptitle(f"{dataset.upper()}  |  student={student}  teacher={teacher}",
                 fontsize=12, fontweight="bold")
    fig.text(0.5, -0.02, DEFINITIONS, ha="center", fontsize=8,
             color="#64748b", style="italic")
    plt.tight_layout()
    plt.savefig(f"fig1_bar_{dataset}.png", dpi=150, bbox_inches="tight")
    plt.show()

    # ── Fig 2: learning curves ─────────────────────────────────────────────────
    fig, axes = plt.subplots(2, 2, figsize=(14, 9))
    axes = axes.flatten()
    for ax, key, title in [
        (axes[0], "HV",               "High-Value Rate vs Budget"),
        (axes[1], "Confident_Noise",  "Confident Noise Rate vs Budget"),
        (axes[2], "student_acc",      "Student Accuracy in Subset"),
        (axes[3], "teacher_acc",      "Teacher Accuracy in Subset"),
    ]:
        for name in scores:
            vals = [results_plot[name][kf][key] for kf in K_FRACS]
            ax.plot(fracs_pct, vals, "o-", label=name, color=METRIC_COLORS[name],
                    linewidth=2, markersize=4)
        ax.set_xlabel("Budget (%)")
        ax.set_title(title, fontsize=11, fontweight="bold")
        ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
        ax.legend(fontsize=7)

    fig.suptitle(f"{dataset.upper()}  |  student={student}  teacher={teacher}",
                 fontsize=12, fontweight="bold")
    plt.tight_layout()
    plt.savefig(f"fig2_curves_{dataset}.png", dpi=150, bbox_inches="tight")
    plt.show()

    # ── Fig 3: scatter ─────────────────────────────────────────────────────────
    H_s_range = np.percentile(H_s, 99.5) * 1.05
    H_t_range = H_t.max() * 1.05
    rng = np.random.RandomState(42)
    sample_idx = rng.choice(len(df), min(4000, len(df)), replace=False)

    cats = np.full(len(df), "other", dtype=object)
    cats[is_hv]  = "high_value"
    cats[is_noisy & ~sc] = "noisy"
    cats[~tc & sc] = "student_only"
    cat_colors = {"high_value": "#22c55e", "noisy": "#ef4444",
                  "student_only": "#f59e0b", "other": "#cbd5e1"}
    cat_labels = {
        "high_value":   "HV: T✓ S✗",
        "noisy":        "Noisy: T✗ S✗",
        "student_only": "S✓ T✗",
        "other":        "Both correct",
    }
    fig, ax = plt.subplots(figsize=(8, 6))
    for cat in ["other", "noisy", "student_only", "high_value"]:
        mask = cats[sample_idx] == cat
        ax.scatter(H_t[sample_idx][mask], H_s[sample_idx][mask],
                   c=cat_colors[cat], s=6, alpha=0.35,
                   label=cat_labels[cat], edgecolors="none")
    ax.set_xlabel("Ĥ(teacher)"); ax.set_ylabel("Ĥ(student)")
    ax.set_title(f"Ĥ(s) vs Ĥ(t)  [{dataset} | {student}]",
                 fontsize=12, fontweight="bold")
    ax.legend(fontsize=9, markerscale=3)
    plt.tight_layout()
    plt.savefig(f"fig3_scatter_{dataset}.png", dpi=150, bbox_inches="tight")
    plt.show()

print("\n✓  All figures saved.")
print("✓  Done.")
# Out:
#   [entropy] gpqa_llama_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_llama_70b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=llama_3b  teacher=llama_70b  n=546
#   S.acc=0.282  T.acc=0.515  HV=33.2%  Noisy=48.5%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | llama_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   51.9%         3.7%        0.0%    44.4%    96.3%      +7.7%
#   2. Window-Log (IDS)   51.9%         3.7%        0.0%    44.4%    96.3%      +7.7%
#   3. Random   48.1%        33.3%        3.7%    29.6%    63.0%   baseline
#   4. ER       44.4%        40.7%        0.0%    29.6%    59.3%      -7.7%
#   5. EG       37.0%        48.1%        0.0%    25.9%    51.9%     -23.1%
#   6. LI       33.3%        51.9%        0.0%    29.6%    48.1%     -30.8%
#   7. H        29.6%        51.9%       11.1%    22.2%    37.0%     -38.5%
#   8. Window-Product   29.6%        48.1%        0.0%    25.9%    51.9%     -38.5%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | llama_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   53.7%         5.6%        0.0%    40.7%    94.4%     +52.6%
#   2. Window-Log (IDS)   53.7%         5.6%        0.0%    40.7%    94.4%     +52.6%
#   3. LI       51.9%        38.9%        0.0%    18.5%    61.1%     +47.4%
#   4. EG       48.1%        42.6%        0.0%    18.5%    57.4%     +36.8%
#   5. ER       48.1%        31.5%        0.0%    27.8%    68.5%     +36.8%
#   6. H        38.9%        48.1%        5.6%    18.5%    46.3%     +10.5%
#   7. Window-Product   37.0%        40.7%        0.0%    27.8%    59.3%      +5.3%
#   8. Random   35.2%        38.9%        9.3%    25.9%    51.9%   baseline
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | llama_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   49.5%        14.7%        0.0%    36.7%    85.3%     +50.0%
#   2. Window-Log (IDS)   49.5%        14.7%        0.0%    36.7%    85.3%     +50.0%
#   3. ER       45.9%        32.1%        0.0%    28.4%    67.9%     +38.9%
#   4. EG       44.0%        41.3%        0.0%    21.1%    58.7%     +33.3%
#   5. H        43.1%        42.2%        8.3%    18.3%    49.5%     +30.6%
#   6. LI       43.1%        41.3%        0.0%    22.0%    58.7%     +30.6%
#   7. Window-Product   40.4%        39.4%        0.0%    28.4%    60.6%     +22.2%
#   8. Random   33.0%        37.6%       11.0%    28.4%    51.4%   baseline
#   [entropy] gpqa_phi4mini: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_llama_70b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=phi4mini  teacher=llama_70b  n=546
#   S.acc=0.288  T.acc=0.515  HV=29.5%  Noisy=48.5%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | phi4mini → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Random   59.3%        33.3%        3.7%     3.7%    63.0%   baseline
#   2. Window-Ratio   59.3%         3.7%        0.0%    37.0%    96.3%      +0.0%
#   3. Window-Log (IDS)   59.3%         3.7%        0.0%    37.0%    96.3%      +0.0%
#   4. ER       40.7%        40.7%        0.0%    22.2%    59.3%     -31.2%
#   5. Window-Product   25.9%        51.9%        0.0%    22.2%    48.1%     -56.2%
#   6. LI       22.2%        55.6%        0.0%    40.7%    44.4%     -62.5%
#   7. H        14.8%        55.6%       14.8%    40.7%    29.6%     -75.0%
#   8. EG       14.8%        63.0%        0.0%    44.4%    37.0%     -75.0%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | phi4mini → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   44.4%         7.4%        0.0%    48.1%    92.6%      +4.3%
#   2. Window-Log (IDS)   44.4%         7.4%        0.0%    48.1%    92.6%      +4.3%
#   3. Random   42.6%        38.9%        9.3%    16.7%    51.9%   baseline
#   4. ER       38.9%        35.2%        0.0%    27.8%    64.8%      -8.7%
#   5. Window-Product   27.8%        51.9%        0.0%    22.2%    48.1%     -34.8%
#   6. H        14.8%        57.4%        9.3%    35.2%    33.3%     -65.2%
#   7. EG       14.8%        64.8%        0.0%    33.3%    35.2%     -65.2%
#   8. LI       14.8%        66.7%        0.0%    31.5%    33.3%     -65.2%
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | phi4mini → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   42.2%        13.8%        0.0%    44.0%    86.2%      +9.5%
#   2. Window-Log (IDS)   42.2%        13.8%        0.0%    44.0%    86.2%      +9.5%
#   3. ER       39.4%        31.2%        0.0%    31.2%    68.8%      +2.4%
#   4. Random   38.5%        37.6%       11.0%    19.3%    51.4%   baseline
#   5. Window-Product   31.2%        49.5%        0.0%    22.0%    50.5%     -19.0%
#   6. LI       27.5%        52.3%        0.0%    27.5%    47.7%     -28.6%
#   7. EG       24.8%        55.0%        0.0%    28.4%    45.0%     -35.7%
#   8. H        21.1%        55.0%        8.3%    26.6%    36.7%     -45.2%
#   [entropy] gpqa_qwen_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_llama_70b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=qwen_3b  teacher=llama_70b  n=546
#   S.acc=0.328  T.acc=0.515  HV=30.0%  Noisy=48.5%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | qwen_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   51.9%         3.7%        0.0%    44.4%    96.3%     +55.6%
#   2. Window-Log (IDS)   51.9%         3.7%        0.0%    44.4%    96.3%     +55.6%
#   3. Window-Product   44.4%        37.0%        0.0%    29.6%    63.0%     +33.3%
#   4. EG       40.7%        40.7%        0.0%    29.6%    59.3%     +22.2%
#   5. ER       40.7%        25.9%        0.0%    37.0%    74.1%     +22.2%
#   6. LI       40.7%        37.0%        0.0%    29.6%    63.0%     +22.2%
#   7. Random   33.3%        33.3%        3.7%    40.7%    63.0%   baseline
#   8. H        33.3%        37.0%        7.4%    33.3%    55.6%      +0.0%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | qwen_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   50.0%        11.1%        0.0%    38.9%    88.9%     +58.8%
#   2. Window-Log (IDS)   50.0%        11.1%        0.0%    38.9%    88.9%     +58.8%
#   3. ER       46.3%        20.4%        0.0%    37.0%    79.6%     +47.1%
#   4. Window-Product   37.0%        37.0%        0.0%    35.2%    63.0%     +17.6%
#   5. EG       35.2%        44.4%        0.0%    31.5%    55.6%     +11.8%
#   6. LI       35.2%        42.6%        0.0%    35.2%    57.4%     +11.8%
#   7. Random   31.5%        38.9%        9.3%    31.5%    51.9%   baseline
#   8. H        25.9%        40.7%        7.4%    35.2%    51.9%     -17.6%
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | qwen_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       43.1%        30.3%        0.0%    33.0%    69.7%     +38.2%
#   2. Window-Ratio   42.2%        20.2%        0.0%    41.3%    79.8%     +35.3%
#   3. Window-Log (IDS)   42.2%        20.2%        0.0%    41.3%    79.8%     +35.3%
#   4. Window-Product   40.4%        39.4%        0.0%    28.4%    60.6%     +29.4%
#   5. LI       39.4%        40.4%        0.0%    27.5%    59.6%     +26.5%
#   6. EG       37.6%        41.3%        0.9%    28.4%    57.8%     +20.6%
#   7. Random   31.2%        37.6%       11.0%    33.9%    51.4%   baseline
#   8. H        30.3%        38.5%       10.1%    34.9%    51.4%      -2.9%
#   [entropy] gpqa_llama_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_mistral_24b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=llama_3b  teacher=mistral_24b  n=546
#   S.acc=0.282  T.acc=0.419  HV=27.8%  Noisy=58.1%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | llama_3b → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Product   55.6%        25.9%        7.4%    18.5%    66.7%     +36.4%
#   2. EG       51.9%        18.5%       14.8%    25.9%    66.7%     +27.3%
#   3. Window-Ratio   51.9%        29.6%        7.4%    18.5%    63.0%     +27.3%
#   4. Window-Log (IDS)   51.9%        29.6%        7.4%    18.5%    63.0%     +27.3%
#   5. ER       44.4%        25.9%       14.8%    25.9%    59.3%      +9.1%
#   6. LI       44.4%        22.2%       18.5%    25.9%    59.3%      +9.1%
#   7. Random   40.7%         3.7%       48.1%    29.6%    48.1%   baseline
#   8. H        33.3%         0.0%       51.9%    22.2%    48.1%     -18.2%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | llama_3b → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. EG       53.7%        13.0%       20.4%    18.5%    66.7%    +107.1%
#   2. ER       50.0%        14.8%       22.2%    18.5%    63.0%     +92.9%
#   3. LI       50.0%        13.0%       24.1%    18.5%    63.0%     +92.9%
#   4. Window-Product   48.1%        13.0%       22.2%    24.1%    64.8%     +85.7%
#   5. Window-Ratio   48.1%        14.8%       20.4%    22.2%    64.8%     +85.7%
#   6. Window-Log (IDS)   48.1%        14.8%       20.4%    22.2%    64.8%     +85.7%
#   7. H        33.3%         1.9%       53.7%    18.5%    44.4%     +28.6%
#   8. Random   25.9%         3.7%       61.1%    25.9%    35.2%   baseline
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | llama_3b → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       42.2%         7.3%       37.6%    21.1%    55.0%     +43.8%
#   2. Window-Ratio   40.4%         7.3%       36.7%    22.0%    56.0%     +37.5%
#   3. Window-Log (IDS)   40.4%         7.3%       36.7%    22.0%    56.0%     +37.5%
#   4. EG       39.4%         7.3%       39.4%    20.2%    53.2%     +34.4%
#   5. Window-Product   39.4%         7.3%       38.5%    22.0%    54.1%     +34.4%
#   6. LI       39.4%         7.3%       38.5%    21.1%    54.1%     +34.4%
#   7. H        31.2%         1.8%       60.6%    18.3%    37.6%      +6.2%
#   8. Random   29.4%         1.8%       56.9%    28.4%    41.3%   baseline
#   [entropy] gpqa_phi4mini: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_mistral_24b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=phi4mini  teacher=mistral_24b  n=546
#   S.acc=0.288  T.acc=0.419  HV=23.8%  Noisy=58.1%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | phi4mini → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Random   44.4%         3.7%       48.1%     3.7%    48.1%   baseline
#   2. Window-Product   40.7%        18.5%       14.8%    29.6%    66.7%      -8.3%
#   3. EG       33.3%        18.5%       22.2%    37.0%    59.3%     -25.0%
#   4. ER       33.3%        18.5%       22.2%    37.0%    59.3%     -25.0%
#   5. LI       33.3%        18.5%       22.2%    37.0%    59.3%     -25.0%
#   6. Window-Ratio   29.6%        22.2%       11.1%    40.7%    66.7%     -33.3%
#   7. Window-Log (IDS)   29.6%        22.2%       11.1%    40.7%    66.7%     -33.3%
#   8. H        22.2%         0.0%       66.7%    40.7%    33.3%     -50.0%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | phi4mini → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Product   42.6%        11.1%       22.2%    29.6%    66.7%     +43.8%
#   2. Window-Ratio   42.6%        11.1%       18.5%    31.5%    70.4%     +43.8%
#   3. Window-Log (IDS)   42.6%        11.1%       18.5%    31.5%    70.4%     +43.8%
#   4. EG       33.3%         9.3%       35.2%    31.5%    55.6%     +12.5%
#   5. LI       33.3%         9.3%       35.2%    31.5%    55.6%     +12.5%
#   6. ER       31.5%         9.3%       35.2%    38.9%    55.6%      +6.3%
#   7. Random   29.6%         3.7%       61.1%    16.7%    35.2%   baseline
#   8. H        20.4%         0.0%       68.5%    35.2%    31.5%     -31.2%
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | phi4mini → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Product   36.7%         5.5%       33.9%    26.6%    60.6%     +17.6%
#   2. Window-Ratio   36.7%         5.5%       33.9%    26.6%    60.6%     +17.6%
#   3. Window-Log (IDS)   36.7%         5.5%       33.9%    26.6%    60.6%     +17.6%
#   4. Random   31.2%         1.8%       56.9%    19.3%    41.3%   baseline
#   5. ER       31.2%         5.5%       44.0%    32.1%    50.5%      +0.0%
#   6. EG       27.5%         4.6%       46.8%    32.1%    48.6%     -11.8%
#   7. LI       27.5%         4.6%       46.8%    32.1%    48.6%     -11.8%
#   8. H        25.7%         0.0%       62.4%    26.6%    37.6%     -17.6%
#   [entropy] gpqa_qwen_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_mistral_24b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=qwen_3b  teacher=mistral_24b  n=546
#   S.acc=0.328  T.acc=0.419  HV=23.1%  Noisy=58.1%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | qwen_3b → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Product   37.0%         0.0%       29.6%    40.7%    70.4%    +100.0%
#   2. Window-Ratio   37.0%         0.0%       29.6%    40.7%    70.4%    +100.0%
#   3. Window-Log (IDS)   37.0%         0.0%       29.6%    40.7%    70.4%    +100.0%
#   4. ER       33.3%         0.0%       40.7%    40.7%    59.3%     +80.0%
#   5. H        29.6%         0.0%       55.6%    33.3%    44.4%     +60.0%
#   6. EG       22.2%         0.0%       48.1%    48.1%    51.9%     +20.0%
#   7. LI       22.2%         0.0%       44.4%    51.9%    55.6%     +20.0%
#   8. Random   18.5%         3.7%       48.1%    40.7%    48.1%   baseline
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | qwen_3b → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       33.3%         0.0%       48.1%    35.2%    51.9%    +157.1%
#   2. Window-Product   31.5%         1.9%       40.7%    33.3%    57.4%    +142.9%
#   3. Window-Ratio   29.6%         1.9%       42.6%    35.2%    55.6%    +128.6%
#   4. Window-Log (IDS)   29.6%         1.9%       42.6%    35.2%    55.6%    +128.6%
#   5. EG       25.9%         0.0%       50.0%    48.1%    50.0%    +100.0%
#   6. LI       25.9%         0.0%       50.0%    48.1%    50.0%    +100.0%
#   7. H        24.1%         0.0%       61.1%    35.2%    38.9%     +85.7%
#   8. Random   13.0%         3.7%       61.1%    31.5%    35.2%   baseline
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | qwen_3b → mistral_24b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Product   27.5%         1.8%       51.4%    33.0%    46.8%     +25.0%
#   2. ER       25.7%         0.0%       54.1%    35.8%    45.9%     +16.7%
#   3. Window-Ratio   25.7%         0.9%       54.1%    32.1%    45.0%     +16.7%
#   4. Window-Log (IDS)   25.7%         0.9%       54.1%    32.1%    45.0%     +16.7%
#   5. H        22.9%         0.0%       61.5%    34.9%    38.5%      +4.2%
#   6. Random   22.0%         1.8%       56.9%    33.9%    41.3%   baseline
#   7. EG       22.0%         0.9%       52.3%    42.2%    46.8%      +0.0%
#   8. LI       22.0%         0.9%       52.3%    42.2%    46.8%      +0.0%
#   [entropy] gpqa_llama_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_qwen_32b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=llama_3b  teacher=qwen_32b  n=546
#   S.acc=0.282  T.acc=0.407  HV=26.4%  Noisy=59.3%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | llama_3b → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       51.9%        29.6%        0.0%    25.9%    70.4%    +100.0%
#   2. Window-Ratio   44.4%        29.6%        0.0%    37.0%    70.4%     +71.4%
#   3. Window-Log (IDS)   44.4%        29.6%        0.0%    37.0%    70.4%     +71.4%
#   4. EG       40.7%        44.4%        0.0%    14.8%    55.6%     +57.1%
#   5. LI       40.7%        44.4%        0.0%    14.8%    55.6%     +57.1%
#   6. H        37.0%        37.0%       14.8%    22.2%    48.1%     +42.9%
#   7. Window-Product   33.3%        44.4%        0.0%    25.9%    55.6%     +28.6%
#   8. Random   25.9%        59.3%        3.7%    29.6%    37.0%   baseline
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | llama_3b → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       42.6%        38.9%        0.0%    25.9%    61.1%     +91.7%
#   2. EG       40.7%        44.4%        0.0%    24.1%    55.6%     +83.3%
#   3. LI       40.7%        46.3%        0.0%    24.1%    53.7%     +83.3%
#   4. Window-Ratio   38.9%        33.3%        0.0%    35.2%    66.7%     +75.0%
#   5. Window-Log (IDS)   38.9%        33.3%        0.0%    35.2%    66.7%     +75.0%
#   6. H        33.3%        29.6%       27.8%    18.5%    42.6%     +50.0%
#   7. Window-Product   29.6%        51.9%        0.0%    27.8%    48.1%     +33.3%
#   8. Random   22.2%        57.4%       11.1%    25.9%    31.5%   baseline
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | llama_3b → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. H        34.9%        33.9%       22.9%    18.3%    43.1%     +22.6%
#   2. EG       34.9%        51.4%        0.0%    25.7%    48.6%     +22.6%
#   3. ER       33.9%        46.8%        0.0%    31.2%    53.2%     +19.4%
#   4. Window-Ratio   33.9%        45.9%        0.0%    32.1%    54.1%     +19.4%
#   5. Window-Log (IDS)   33.9%        45.9%        0.0%    32.1%    54.1%     +19.4%
#   6. LI       33.0%        53.2%        0.0%    25.7%    46.8%     +16.1%
#   7. Random   28.4%        43.1%       15.6%    28.4%    41.3%   baseline
#   8. Window-Product   27.5%        62.4%        0.0%    21.1%    37.6%      -3.2%
#   [entropy] gpqa_phi4mini: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_qwen_32b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=phi4mini  teacher=qwen_32b  n=546
#   S.acc=0.288  T.acc=0.407  HV=22.7%  Noisy=59.3%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | phi4mini → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Random   33.3%        59.3%        3.7%     3.7%    37.0%   baseline
#   2. Window-Product   33.3%        63.0%        0.0%    18.5%    37.0%      +0.0%
#   3. Window-Ratio   33.3%        29.6%        0.0%    40.7%    70.4%      +0.0%
#   4. Window-Log (IDS)   33.3%        29.6%        0.0%    40.7%    70.4%      +0.0%
#   5. H        29.6%        22.2%       37.0%    40.7%    40.7%     -11.1%
#   6. ER       29.6%        37.0%        0.0%    40.7%    63.0%     -11.1%
#   7. EG       25.9%        66.7%        0.0%    22.2%    33.3%     -22.2%
#   8. LI       25.9%        66.7%        0.0%    22.2%    33.3%     -22.2%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | phi4mini → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. LI       31.5%        61.1%        0.0%    20.4%    38.9%     +21.4%
#   2. EG       29.6%        59.3%        0.0%    22.2%    40.7%     +14.3%
#   3. ER       27.8%        40.7%        0.0%    37.0%    59.3%      +7.1%
#   4. Random   25.9%        57.4%       11.1%    16.7%    31.5%   baseline
#   5. Window-Product   25.9%        66.7%        0.0%    20.4%    33.3%      +0.0%
#   6. Window-Ratio   22.2%        35.2%        0.0%    48.1%    64.8%     -14.3%
#   7. Window-Log (IDS)   22.2%        35.2%        0.0%    48.1%    64.8%     -14.3%
#   8. H        20.4%        29.6%       35.2%    35.2%    35.2%     -21.4%
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | phi4mini → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Random   31.2%        43.1%       15.6%    19.3%    41.3%   baseline
#   2. Window-Product   28.4%        58.7%        0.0%    24.8%    41.3%      -8.8%
#   3. LI       27.5%        59.6%        0.0%    26.6%    40.4%     -11.8%
#   4. EG       26.6%        60.6%        0.0%    25.7%    39.4%     -14.7%
#   5. ER       24.8%        45.9%        0.0%    36.7%    54.1%     -20.6%
#   6. Window-Ratio   22.9%        45.0%        0.0%    39.4%    55.0%     -26.5%
#   7. Window-Log (IDS)   22.9%        45.0%        0.0%    39.4%    55.0%     -26.5%
#   8. H        20.2%        32.1%       34.9%    26.6%    33.0%     -35.3%
#   [entropy] gpqa_qwen_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_qwen_32b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=qwen_3b  teacher=qwen_32b  n=546
#   S.acc=0.328  T.acc=0.407  HV=21.2%  Noisy=59.3%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | qwen_3b → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. EG       25.9%        48.1%        0.0%    44.4%    51.9%     +75.0%
#   2. LI       22.2%        48.1%        0.0%    48.1%    51.9%     +50.0%
#   3. H        18.5%        29.6%       40.7%    33.3%    29.6%     +25.0%
#   4. Random   14.8%        59.3%        3.7%    40.7%    37.0%   baseline
#   5. Window-Ratio   14.8%        44.4%        0.0%    55.6%    55.6%      +0.0%
#   6. Window-Log (IDS)   14.8%        44.4%        0.0%    55.6%    55.6%      +0.0%
#   7. Window-Product   11.1%        59.3%        0.0%    40.7%    40.7%     -25.0%
#   8. ER        7.4%        59.3%        0.0%    48.1%    40.7%     -50.0%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | qwen_3b → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       22.2%        50.0%        0.0%    40.7%    50.0%     +50.0%
#   2. EG       20.4%        55.6%        1.9%    37.0%    42.6%     +37.5%
#   3. LI       20.4%        53.7%        0.0%    40.7%    46.3%     +37.5%
#   4. Window-Ratio   18.5%        51.9%        0.0%    44.4%    48.1%     +25.0%
#   5. Window-Log (IDS)   18.5%        51.9%        0.0%    44.4%    48.1%     +25.0%
#   6. H        16.7%        33.3%       33.3%    35.2%    33.3%     +12.5%
#   7. Random   14.8%        57.4%       11.1%    31.5%    31.5%   baseline
#   8. Window-Product   13.0%        59.3%        0.0%    40.7%    40.7%     -12.5%
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | qwen_3b → qwen_32b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Random   22.0%        43.1%       15.6%    33.9%    41.3%   baseline
#   2. EG       22.0%        49.5%        5.5%    34.9%    45.0%      +0.0%
#   3. ER       22.0%        52.3%        0.0%    41.3%    47.7%      +0.0%
#   4. LI       21.1%        51.4%        3.7%    35.8%    45.0%      -4.2%
#   5. Window-Product   19.3%        56.9%        0.0%    34.9%    43.1%     -12.5%
#   6. Window-Ratio   19.3%        53.2%        0.0%    42.2%    46.8%     -12.5%
#   7. Window-Log (IDS)   19.3%        53.2%        0.0%    42.2%    46.8%     -12.5%
#   8. H        15.6%        36.7%       29.4%    34.9%    33.9%     -29.2%
#   [entropy] gpqa_llama_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_qwen_72b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=llama_3b  teacher=qwen_72b  n=546
#   S.acc=0.282  T.acc=0.408  HV=25.5%  Noisy=59.2%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | llama_3b → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       51.9%        29.6%        0.0%    33.3%    70.4%    +133.3%
#   2. Window-Product   51.9%        29.6%        0.0%    29.6%    70.4%    +133.3%
#   3. EG       44.4%        48.1%        0.0%    25.9%    51.9%    +100.0%
#   4. Window-Ratio   44.4%        18.5%        0.0%    44.4%    81.5%    +100.0%
#   5. Window-Log (IDS)   44.4%        18.5%        0.0%    44.4%    81.5%    +100.0%
#   6. LI       44.4%        40.7%        0.0%    29.6%    59.3%    +100.0%
#   7. Random   22.2%        33.3%       33.3%    29.6%    33.3%   baseline
#   8. H        18.5%        37.0%       33.3%    22.2%    29.6%     -16.7%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | llama_3b → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       50.0%        27.8%        0.0%    29.6%    72.2%    +200.0%
#   2. Window-Ratio   46.3%        27.8%        0.0%    33.3%    72.2%    +177.8%
#   3. Window-Log (IDS)   46.3%        27.8%        0.0%    33.3%    72.2%    +177.8%
#   4. Window-Product   40.7%        40.7%        0.0%    31.5%    59.3%    +144.4%
#   5. EG       31.5%        50.0%        0.0%    29.6%    50.0%     +88.9%
#   6. LI       29.6%        50.0%        0.0%    31.5%    50.0%     +77.8%
#   7. H        24.1%        31.5%       37.0%    18.5%    31.5%     +44.4%
#   8. Random   16.7%        38.9%       33.3%    25.9%    27.8%   baseline
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | llama_3b → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   41.3%        30.3%        0.0%    37.6%    69.7%     +50.0%
#   2. Window-Log (IDS)   41.3%        30.3%        0.0%    37.6%    69.7%     +50.0%
#   3. ER       40.4%        30.3%        0.0%    38.5%    69.7%     +46.7%
#   4. Window-Product   34.9%        48.6%        0.0%    28.4%    51.4%     +26.7%
#   5. LI       30.3%        52.3%        0.0%    28.4%    47.7%     +10.0%
#   6. Random   27.5%        28.4%       31.2%    28.4%    40.4%   baseline
#   7. H        27.5%        30.3%       35.8%    18.3%    33.9%      +0.0%
#   8. EG       26.6%        54.1%        0.9%    30.3%    45.0%      -3.3%
#   [entropy] gpqa_phi4mini: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_qwen_72b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=phi4mini  teacher=qwen_72b  n=546
#   S.acc=0.288  T.acc=0.408  HV=25.5%  Noisy=59.2%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | phi4mini → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Random   33.3%        33.3%       33.3%     3.7%    33.3%   baseline
#   2. ER       33.3%        29.6%        0.0%    37.0%    70.4%      +0.0%
#   3. Window-Product   33.3%        48.1%        0.0%    22.2%    51.9%      +0.0%
#   4. LI       33.3%        51.9%        0.0%    18.5%    48.1%      +0.0%
#   5. EG       29.6%        51.9%        3.7%    22.2%    44.4%     -11.1%
#   6. Window-Ratio   18.5%        14.8%        0.0%    66.7%    85.2%     -44.4%
#   7. Window-Log (IDS)   18.5%        14.8%        0.0%    66.7%    85.2%     -44.4%
#   8. H        14.8%        14.8%       63.0%    40.7%    22.2%     -55.6%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | phi4mini → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       29.6%        27.8%        0.0%    44.4%    72.2%     +14.3%
#   2. Window-Product   27.8%        48.1%        0.0%    31.5%    51.9%      +7.1%
#   3. Random   25.9%        38.9%       33.3%    16.7%    27.8%   baseline
#   4. EG       25.9%        51.9%        3.7%    27.8%    44.4%      +0.0%
#   5. Window-Ratio   25.9%        25.9%        0.0%    50.0%    74.1%      +0.0%
#   6. Window-Log (IDS)   25.9%        25.9%        0.0%    50.0%    74.1%      +0.0%
#   7. LI       25.9%        53.7%        0.0%    27.8%    46.3%      +0.0%
#   8. H        16.7%        14.8%       59.3%    35.2%    25.9%     -35.7%
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | phi4mini → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Random   32.1%        28.4%       31.2%    19.3%    40.4%   baseline
#   2. LI       31.2%        46.8%        0.0%    27.5%    53.2%      -2.9%
#   3. EG       30.3%        46.8%        3.7%    27.5%    49.5%      -5.7%
#   4. ER       30.3%        30.3%        0.0%    44.0%    69.7%      -5.7%
#   5. Window-Ratio   30.3%        30.3%        0.0%    44.0%    69.7%      -5.7%
#   6. Window-Log (IDS)   30.3%        30.3%        0.0%    44.0%    69.7%      -5.7%
#   7. Window-Product   29.4%        50.5%        0.0%    27.5%    49.5%      -8.6%
#   8. H        22.0%        20.2%       50.5%    26.6%    29.4%     -31.4%
#   [entropy] gpqa_qwen_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_qwen_72b: using 'entropy_value', correct='model_answer_correct'
#
# [gpqa] student=qwen_3b  teacher=qwen_72b  n=546
#   S.acc=0.328  T.acc=0.408  HV=21.4%  Noisy=59.2%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gpqa | qwen_3b → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       44.4%        22.2%        0.0%    37.0%    77.8%    +200.0%
#   2. Window-Ratio   40.7%        25.9%        0.0%    37.0%    74.1%    +175.0%
#   3. Window-Log (IDS)   40.7%        25.9%        0.0%    37.0%    74.1%    +175.0%
#   4. Window-Product   33.3%        40.7%        0.0%    33.3%    59.3%    +125.0%
#   5. LI       25.9%        44.4%        0.0%    40.7%    55.6%     +75.0%
#   6. EG       18.5%        59.3%        0.0%    37.0%    40.7%     +25.0%
#   7. Random   14.8%        33.3%       33.3%    40.7%    33.3%   baseline
#   8. H        14.8%        33.3%       40.7%    33.3%    25.9%      +0.0%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gpqa | qwen_3b → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   31.5%        25.9%        0.0%    48.1%    74.1%    +112.5%
#   2. Window-Log (IDS)   31.5%        25.9%        0.0%    48.1%    74.1%    +112.5%
#   3. EG       27.8%        50.0%        1.9%    33.3%    48.1%     +87.5%
#   4. ER       27.8%        29.6%        0.0%    48.1%    70.4%     +87.5%
#   5. Window-Product   24.1%        50.0%        0.0%    37.0%    50.0%     +62.5%
#   6. LI       24.1%        51.9%        1.9%    35.2%    46.3%     +62.5%
#   7. H        16.7%        29.6%       31.5%    35.2%    38.9%     +12.5%
#   8. Random   14.8%        38.9%       33.3%    31.5%    27.8%   baseline
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gpqa | qwen_3b → qwen_72b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       29.4%        44.0%        0.0%    34.9%    56.0%     +23.1%
#   2. Window-Ratio   25.7%        41.3%        0.0%    40.4%    58.7%      +7.7%
#   3. Window-Log (IDS)   25.7%        41.3%        0.0%    40.4%    58.7%      +7.7%
#   4. EG       24.8%        41.3%       12.8%    32.1%    45.9%      +3.8%
#   5. Random   23.9%        28.4%       31.2%    33.9%    40.4%   baseline
#   6. LI       23.9%        44.0%       10.1%    32.1%    45.9%      +0.0%
#   7. Window-Product   22.9%        39.4%       14.7%    34.9%    45.9%      -3.8%
#   8. H        18.3%        22.9%       38.5%    34.9%    38.5%     -23.1%
#   [entropy] gsm8k_llama_3b: using 'first_token_entropy', correct='model_answer_correct'
#   [entropy] gsm8k_llama_70b: using 'first_token_entropy', correct='model_answer_correct'
#
# [gsm8k] student=llama_3b  teacher=llama_70b  n=7473
#   S.acc=0.003  T.acc=0.114  HV=11.2%  Noisy=88.6%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gsm8k | llama_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   63.8%        33.0%        0.0%     3.2%    67.0%    +495.0%
#   2. Window-Log (IDS)   63.8%        33.0%        0.0%     3.2%    67.0%    +495.0%
#   3. ER       58.7%        38.1%        0.0%     3.2%    61.9%    +447.5%
#   4. Window-Product   22.3%        76.4%        0.0%     1.6%    23.6%    +107.5%
#   5. LI       14.7%        85.3%        0.0%     0.3%    14.7%     +37.5%
#   6. EG       12.6%        87.1%        0.3%     0.0%    12.6%     +17.5%
#   7. Random   10.7%        75.1%       13.9%     0.3%    11.0%   baseline
#   8. H         4.3%        74.3%       21.4%     0.3%     4.3%     -60.0%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gsm8k | llama_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   46.2%        51.9%        0.0%     2.0%    48.1%    +320.7%
#   2. Window-Log (IDS)   46.2%        51.9%        0.0%     2.0%    48.1%    +320.7%
#   3. ER       45.5%        52.6%        0.0%     2.0%    47.4%    +314.6%
#   4. Window-Product   17.1%        82.1%        0.0%     1.1%    17.9%     +56.1%
#   5. LI       12.6%        86.7%        0.0%     0.8%    13.3%     +14.6%
#   6. EG       11.1%        88.2%        0.5%     0.4%    11.2%      +1.2%
#   7. Random   11.0%        77.4%       11.5%     0.1%    11.1%   baseline
#   8. H         5.1%        75.9%       19.0%     0.1%     5.1%     -53.7%
#
# ===================================================================================================================
#   RANKING TABLE — top 20%   [gsm8k | llama_3b → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   31.3%        67.8%        0.0%     1.1%    32.2%    +165.3%
#   2. Window-Log (IDS)   31.3%        67.8%        0.0%     1.1%    32.2%    +165.3%
#   3. ER       30.3%        68.7%        0.0%     1.1%    31.3%    +157.4%
#   4. Window-Product   13.0%        86.5%        0.0%     0.7%    13.5%     +10.2%
#   5. Random   11.8%        75.6%       12.4%     0.3%    12.0%   baseline
#   6. LI       11.8%        87.8%        0.1%     0.6%    12.2%      +0.0%
#   7. EG       10.9%        88.2%        0.5%     0.6%    11.3%      -7.4%
#   8. H         5.6%        75.0%       19.4%     0.2%     5.6%     -52.3%
#   [entropy] gsm8k_phi4mini: using 'first_token_entropy', correct='model_answer_correct'
#   [entropy] gsm8k_llama_70b: using 'first_token_entropy', correct='model_answer_correct'
#
# [gsm8k] student=phi4mini  teacher=llama_70b  n=7473
#   S.acc=0.067  T.acc=0.114  HV=8.2%  Noisy=88.6%
#
# ===================================================================================================================
#   RANKING TABLE — top 5%   [gsm8k | phi4mini → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. ER       42.1%        35.4%        0.0%    23.3%    64.6%    +441.4%
#   2. Window-Ratio   41.6%        31.9%        0.0%    27.3%    68.1%    +434.5%
#   3. Window-Log (IDS)   41.6%        31.9%        0.0%    27.3%    68.1%    +434.5%
#   4. Window-Product   18.0%        75.9%        0.0%     8.0%    24.1%    +131.0%
#   5. Random    7.8%        75.1%       13.9%     6.7%    11.0%   baseline
#   6. LI        4.8%        94.9%        0.0%     1.6%     5.1%     -37.9%
#   7. EG        2.7%        97.1%        0.0%     1.6%     2.9%     -65.5%
#   8. H         1.9%        85.0%       12.6%     1.6%     2.4%     -75.9%
#
# ===================================================================================================================
#   RANKING TABLE — top 10%   [gsm8k | phi4mini → llama_70b]
# ===================================================================================================================
#   Metric       HV%   ConfNoise%   UncNoise%   S.Acc   T.Acc   Lift HV
# -------------------------------------------------------------------------------------------------------------------
#   1. Window-Ratio   31.5%        51.1%        0.0%    19.3%    48.9%    +305.2%
# ...
#  qwen_3b mistral_24b Window-Log (IDS) 16.2%           20.1%             57.2%       15.0%       22.8%
#  qwen_3b mistral_24b               LI  7.2%           13.8%             76.4%        7.9%        9.8%
# llama_3b    qwen_32b           Random 59.4%           32.0%              8.4%        0.1%       59.6%
# llama_3b    qwen_32b                H 49.5%           38.2%             12.3%        0.1%       49.5%
# llama_3b    qwen_32b               EG 62.5%           37.5%              0.0%        0.3%       62.5%
# llama_3b    qwen_32b               ER 81.0%           18.7%              0.0%        0.4%       81.3%
# llama_3b    qwen_32b   Window-Product 72.6%           27.2%              0.0%        0.4%       72.8%
# llama_3b    qwen_32b     Window-Ratio 92.2%            6.0%              0.0%        1.7%       94.0%
# llama_3b    qwen_32b Window-Log (IDS) 92.2%            6.0%              0.0%        1.7%       94.0%
# llama_3b    qwen_32b               LI 64.3%           35.7%              0.0%        0.3%       64.3%
# phi4mini    qwen_32b           Random 53.7%           32.0%              8.4%        6.3%       59.6%
# phi4mini    qwen_32b                H 46.1%           41.8%             11.0%        1.5%       47.3%
# phi4mini    qwen_32b               EG 57.0%           41.2%              0.0%        2.3%       58.8%
# phi4mini    qwen_32b               ER 73.2%           23.3%              0.0%        4.0%       76.7%
# phi4mini    qwen_32b   Window-Product 70.5%           21.7%              0.0%        8.0%       78.3%
# phi4mini    qwen_32b     Window-Ratio 71.2%            5.6%              0.0%       23.6%       94.4%
# phi4mini    qwen_32b Window-Log (IDS) 71.2%            5.6%              0.0%       23.6%       94.4%
# phi4mini    qwen_32b               LI 58.1%           40.2%              0.0%        2.3%       59.8%
#  qwen_3b    qwen_32b           Random 44.4%           32.0%              8.4%       17.5%       59.6%
#  qwen_3b    qwen_32b                H 41.1%           39.0%             17.8%        3.9%       43.2%
#  qwen_3b    qwen_32b               EG 52.6%           43.2%              0.4%        4.8%       56.4%
#  qwen_3b    qwen_32b               ER 67.6%           21.3%              0.0%       11.9%       78.7%
#  qwen_3b    qwen_32b   Window-Product 60.8%           29.7%              0.0%       10.8%       70.3%
#  qwen_3b    qwen_32b     Window-Ratio 62.4%            7.5%              0.0%       30.9%       92.5%
#  qwen_3b    qwen_32b Window-Log (IDS) 62.4%            7.5%              0.0%       30.9%       92.5%
#  qwen_3b    qwen_32b               LI 54.8%           41.0%              0.0%        5.2%       59.0%
# llama_3b    qwen_72b           Random 52.6%           35.6%             11.6%        0.1%       52.7%
# llama_3b    qwen_72b                H 39.9%           40.2%             19.9%        0.1%       39.9%
# llama_3b    qwen_72b               EG 57.7%           42.0%              0.3%        0.3%       57.7%
# llama_3b    qwen_72b               ER 81.9%           16.9%              0.0%        1.3%       83.1%
# llama_3b    qwen_72b   Window-Product 68.3%           31.3%              0.0%        0.5%       68.7%
# llama_3b    qwen_72b     Window-Ratio 91.7%            6.7%              0.0%        1.6%       93.3%
# llama_3b    qwen_72b Window-Log (IDS) 91.7%            6.7%              0.0%        1.6%       93.3%
# llama_3b    qwen_72b               LI 60.1%           39.8%              0.0%        0.4%       60.2%
# phi4mini    qwen_72b           Random 47.4%           35.6%             11.6%        6.3%       52.7%
# phi4mini    qwen_72b                H 36.4%           43.4%             19.3%        1.5%       37.3%
# phi4mini    qwen_72b               EG 49.3%           49.0%              0.0%        2.5%       51.0%
# phi4mini    qwen_72b               ER 71.8%           20.7%              0.0%        8.0%       79.3%
# phi4mini    qwen_72b   Window-Product 66.3%           25.2%              0.0%        9.0%       74.8%
# phi4mini    qwen_72b     Window-Ratio 68.3%            5.9%              0.0%       26.1%       94.1%
# phi4mini    qwen_72b Window-Log (IDS) 68.3%            5.9%              0.0%       26.1%       94.1%
# phi4mini    qwen_72b               LI 51.9%           45.9%              0.0%        2.8%       54.1%
#  qwen_3b    qwen_72b           Random 38.3%           35.6%             11.6%       17.5%       52.7%
#  qwen_3b    qwen_72b                H 27.7%           43.6%             26.9%        3.9%       29.5%
#  qwen_3b    qwen_72b               EG 41.9%           53.4%              1.2%        5.8%       45.4%
#  qwen_3b    qwen_72b               ER 64.4%           18.6%              0.0%       17.8%       81.4%
#  qwen_3b    qwen_72b   Window-Product 53.0%           37.5%              0.0%       11.2%       62.5%
#  qwen_3b    qwen_72b     Window-Ratio 58.8%            8.2%              0.0%       34.1%       91.8%
#  qwen_3b    qwen_72b Window-Log (IDS) 58.8%            8.2%              0.0%       34.1%       91.8%
#  qwen_3b    qwen_72b               LI 45.0%           50.6%              0.0%        6.4%       49.4%
#
#
# ===================================================================================================================
#   DATASET: MMLU
# ===================================================================================================================
#  Student     Teacher           Metric    HV Confident_Noise Uncertainty_Noise student_acc teacher_acc
# llama_3b   llama_70b           Random 32.1%           39.7%              7.4%       27.3%       53.0%
# llama_3b   llama_70b                H 25.6%           51.1%             19.0%       12.4%       29.9%
# llama_3b   llama_70b               EG 37.4%           54.7%              0.2%       15.3%       45.1%
# llama_3b   llama_70b               ER 47.8%           38.2%              0.0%       19.7%       61.8%
# llama_3b   llama_70b   Window-Product 43.9%           43.1%              0.0%       19.2%       56.9%
# llama_3b   llama_70b     Window-Ratio 46.2%           11.4%              0.0%       43.9%       88.6%
# llama_3b   llama_70b Window-Log (IDS) 46.2%           11.4%              0.0%       43.9%       88.6%
# llama_3b   llama_70b               LI 37.9%           53.7%              0.0%       16.0%       46.3%
# phi4mini   llama_70b           Random 23.9%           39.7%              7.4%       36.2%       53.0%
# phi4mini   llama_70b                H 19.0%           54.1%             21.1%       15.3%       24.8%
# phi4mini   llama_70b               EG 23.9%           66.7%              0.0%       18.0%       33.3%
# phi4mini   llama_70b               ER 33.8%           46.4%              0.0%       27.8%       53.6%
# phi4mini   llama_70b   Window-Product 32.6%           49.1%              0.0%       27.3%       50.9%
# phi4mini   llama_70b     Window-Ratio 31.8%           14.0%              0.0%       56.0%       86.0%
# phi4mini   llama_70b Window-Log (IDS) 31.8%           14.0%              0.0%       56.0%       86.0%
# phi4mini   llama_70b               LI 24.3%           65.4%              0.0%       19.1%       34.6%
#  qwen_3b   llama_70b           Random 25.4%           39.7%              7.4%       36.0%       53.0%
#  qwen_3b   llama_70b                H 22.9%           53.2%             18.3%       16.5%       28.5%
#  qwen_3b   llama_70b               EG 28.3%           62.3%              1.9%       17.5%       35.8%
#  qwen_3b   llama_70b               ER 42.6%           40.2%              0.0%       23.0%       59.8%
#  qwen_3b   llama_70b   Window-Product 32.6%           57.8%              0.0%       19.0%       42.2%
#  qwen_3b   llama_70b     Window-Ratio 47.2%           20.9%              0.0%       34.7%       79.1%
#  qwen_3b   llama_70b Window-Log (IDS) 47.2%           20.9%              0.0%       34.7%       79.1%
#  qwen_3b   llama_70b               LI 29.2%           62.8%              0.1%       18.0%       37.2%
# llama_3b mistral_24b           Random 30.2%            6.8%             42.9%       27.3%       50.3%
# llama_3b mistral_24b                H 26.4%            1.2%             67.6%       12.4%       31.3%
# llama_3b mistral_24b               EG 52.5%           20.7%              3.8%       25.8%       75.5%
# llama_3b mistral_24b               ER 51.1%           19.9%              0.6%       30.9%       79.6%
# llama_3b mistral_24b   Window-Product 51.9%           21.4%              0.0%       29.6%       78.6%
# llama_3b mistral_24b     Window-Ratio 48.5%           17.3%              0.0%       36.5%       82.7%
# llama_3b mistral_24b Window-Log (IDS) 48.5%           17.3%              0.0%       36.5%       82.7%
# llama_3b mistral_24b               LI 52.5%           20.8%              1.4%       27.8%       77.8%
# phi4mini mistral_24b           Random 21.4%            6.8%             42.9%       36.2%       50.3%
# phi4mini mistral_24b                H 20.7%            0.2%             73.7%       15.3%       26.1%
# phi4mini mistral_24b               EG 37.1%           16.0%             21.4%       31.2%       62.7%
# phi4mini mistral_24b               ER 37.5%           20.0%              9.6%       37.6%       70.3%
# phi4mini mistral_24b   Window-Product 39.2%           20.9%              8.6%       35.7%       70.4%
# phi4mini mistral_24b     Window-Ratio 35.7%           23.7%              0.1%       44.2%       76.2%
# phi4mini mistral_24b Window-Log (IDS) 35.7%           23.7%              0.1%       44.2%       76.2%
# phi4mini mistral_24b               LI 38.1%           18.8%             13.3%       35.0%       67.9%
#  qwen_3b mistral_24b           Random 22.1%            6.8%             42.9%       36.0%       50.3%
#  qwen_3b mistral_24b                H 21.7%            3.2%             68.9%       16.5%       27.8%
#  qwen_3b mistral_24b               EG 39.9%           14.0%             29.6%       22.9%       56.4%
#  qwen_3b mistral_24b               ER 39.9%           13.5%             31.8%       21.7%       54.7%
#  qwen_3b mistral_24b   Window-Product 43.9%           14.9%             23.5%       23.4%       61.6%
#  qwen_3b mistral_24b     Window-Ratio 44.9%           17.5%             17.3%       25.8%       65.2%
#  qwen_3b mistral_24b Window-Log (IDS) 44.9%           17.5%             17.3%       25.8%       65.2%
#  qwen_3b mistral_24b               LI 40.0%           13.9%             29.4%       22.9%       56.7%
# llama_3b    qwen_32b           Random 36.3%           42.6%              0.2%       27.3%       57.2%
# llama_3b    qwen_32b                H 33.3%           61.0%              0.2%       12.4%       38.7%
# llama_3b    qwen_32b               EG 43.6%           48.3%              0.0%       14.0%       51.7%
# llama_3b    qwen_32b               ER 57.7%           22.4%              0.0%       22.4%       77.6%
# llama_3b    qwen_32b   Window-Product 51.8%           33.4%              0.0%       19.5%       66.6%
# llama_3b    qwen_32b     Window-Ratio 49.5%           16.1%              0.0%       36.5%       83.9%
# llama_3b    qwen_32b Window-Log (IDS) 49.5%           16.1%              0.0%       36.5%       83.9%
# llama_3b    qwen_32b               LI 44.6%           46.3%              0.0%       14.5%       53.7%
# phi4mini    qwen_32b           Random 27.3%           42.6%              0.2%       36.2%       57.2%
# phi4mini    qwen_32b                H 28.4%           64.2%              0.0%       15.3%       35.8%
# phi4mini    qwen_32b               EG 33.5%           57.0%              0.0%       17.2%       43.0%
# phi4mini    qwen_32b               ER 41.7%           24.4%              0.0%       36.9%       75.6%
# phi4mini    qwen_32b   Window-Product 37.0%           40.4%              0.0%       27.9%       59.6%
# phi4mini    qwen_32b     Window-Ratio 33.3%           16.9%              0.0%       51.3%       83.1%
# phi4mini    qwen_32b Window-Log (IDS) 33.3%           16.9%              0.0%       51.3%       83.1%
# phi4mini    qwen_32b               LI 34.7%           52.6%              0.0%       20.2%       47.4%
#  qwen_3b    qwen_32b           Random 27.6%           42.6%              0.2%       36.0%       57.2%
#  qwen_3b    qwen_32b                H 28.7%           62.8%              0.4%       16.5%       36.8%
#  qwen_3b    qwen_32b               EG 31.0%           59.5%              0.0%       17.6%       40.5%
#  qwen_3b    qwen_32b               ER 49.5%           26.6%              0.0%       27.0%       73.4%
#  qwen_3b    qwen_32b   Window-Product 34.6%           52.9%              0.0%       20.0%       47.1%
#  qwen_3b    qwen_32b     Window-Ratio 47.7%           20.7%              0.0%       34.0%       79.3%
#  qwen_3b    qwen_32b Window-Log (IDS) 47.7%           20.7%              0.0%       34.0%       79.3%
#  qwen_3b    qwen_32b               LI 31.3%           58.0%              0.0%       18.7%       42.0%
# llama_3b    qwen_72b           Random 32.2%           25.4%             20.8%       27.3%       53.8%
# llama_3b    qwen_72b                H 27.4%           28.5%             37.9%       12.4%       33.6%
# llama_3b    qwen_72b               EG 51.5%           34.4%              0.1%       18.1%       65.5%
# llama_3b    qwen_72b               ER 53.4%            9.1%              0.0%       39.2%       90.9%
# llama_3b    qwen_72b   Window-Product 57.0%           23.5%              0.0%       22.9%       76.5%
# llama_3b    qwen_72b     Window-Ratio 30.3%            4.2%              0.0%       65.8%       95.8%
# llama_3b    qwen_72b Window-Log (IDS) 30.3%            4.2%              0.0%       65.8%       95.8%
# llama_3b    qwen_72b               LI 54.1%           31.3%              0.0%       18.4%       68.7%
# phi4mini    qwen_72b           Random 25.2%           25.4%             20.8%       36.2%       53.8%
# phi4mini    qwen_72b                H 22.5%           29.7%             41.8%       15.3%       28.5%
# phi4mini    qwen_72b               EG 33.4%           50.6%              0.7%       21.7%       48.7%
# phi4mini    qwen_72b               ER 36.6%           10.1%              0.0%       53.8%       89.9%
# phi4mini    qwen_72b   Window-Product 41.1%           32.6%              0.0%       31.5%       67.4%
# phi4mini    qwen_72b     Window-Ratio 16.0%            4.8%              0.0%       79.3%       95.2%
# phi4mini    qwen_72b Window-Log (IDS) 16.0%            4.8%              0.0%       79.3%       95.2%
# phi4mini    qwen_72b               LI 35.8%           46.8%              0.0%       23.6%       53.2%
#  qwen_3b    qwen_72b           Random 24.3%           25.4%             20.8%       36.0%       53.8%
#  qwen_3b    qwen_72b                H 22.6%           29.3%             41.5%       16.5%       29.2%
#  qwen_3b    qwen_72b               EG 37.4%           42.1%              7.1%       20.4%       50.9%
#  qwen_3b    qwen_72b               ER 50.5%           16.7%              0.0%       34.8%       83.3%
#  qwen_3b    qwen_72b   Window-Product 40.7%           43.0%              0.0%       22.0%       57.0%
#  qwen_3b    qwen_72b     Window-Ratio 43.1%            9.8%              0.0%       48.1%       90.2%
#  qwen_3b    qwen_72b Window-Log (IDS) 43.1%            9.8%              0.0%       48.1%       90.2%
#  qwen_3b    qwen_72b               LI 40.0%           43.4%              2.0%       20.9%       54.6%
#
# [plots] gpqa: student=qwen_3b  teacher=qwen_72b
#   [entropy] gpqa_qwen_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] gpqa_qwen_72b: using 'entropy_value', correct='model_answer_correct'
# [plots] gsm8k: student=qwen_3b  teacher=qwen_72b
#   [entropy] gsm8k_qwen_3b: using 'first_token_entropy', correct='model_answer_correct'
#   [entropy] gsm8k_qwen_72b: using 'first_token_entropy', correct='model_answer_correct'
# [plots] mmlu: student=qwen_3b  teacher=qwen_72b
#   [entropy] mmlu_qwen_3b: using 'entropy_value', correct='model_answer_correct'
#   [entropy] mmlu_qwen_72b: using 'entropy_value', correct='model_answer_correct'
# ✓  All figures saved.
# ✓  Done.
